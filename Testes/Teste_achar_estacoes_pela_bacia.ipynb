# %%
from DownloadDados import *

Downloader = DownloadANA()

# Definição dos caminhos dos arquivos shapefile
shapefile_bacia = r'C:\Projetos\Metodos Estatisticos 1\Metodos Estatisticos\Finalizados\Base de dados\1 etapa\bacia_suav.shp'
shapefile_ANA = r'C:\Projetos\Metodos Estatisticos 1\Metodos Estatisticos\Finalizados\Base de dados\1 etapa\Estações_Fluviométricas_e_Pluviométricas_da_Rede.shp'
shapefile_rede_drenagem = r'C:\Projetos\Metodos Estatisticos 1\Metodos Estatisticos\Finalizados\Base de dados\1 etapa\rede_drenagem_final.shp'

# Chamando a função para encontrar as estações na bacia
cod_est_P, cod_est_Q, fig = Downloader.achar_estacoes_pela_bacia(shapefile_bacia, shapefile_ANA, shapefile_rede_drenagem)

# Exibindo os códigos das estações encontradas
print("Estações Pluviométricas:", cod_est_P)
print("Estações Fluviométricas:", cod_est_Q)

# Se a figura foi gerada, exibir o gráfico
if fig:
    plt.show()
# Out:
# c:\Users\Enzo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyogrio\raw.py:198: RuntimeWarning: C:\Projetos\Metodos Estatisticos 1\Metodos Estatisticos\Finalizados\Base de dados\1 etapa\bacia_suav.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
# c:\Projetos\Metodos Estatisticos 1\Metodos Estatisticos\Finalizados\DownloadDados.py:262: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   ax.legend()  ## Usando ax.legend() em vez de plt.legend() para garantir que a legenda seja referenciada corretamente
# Estações Pluviométricas: [2244065, 2144083, 2144025, 2144046, 2144018, 2144022, 2144019]
# ...
