# %%
import numpy as np
from matplotlib import pyplot as plt
mu = 5  # Mean of the underlying normal distribution
sigma = 0.5 # Standard deviation of the underlying normal distribution
xs = np.random.lognormal(mean=mu, sigma=sigma, size=200)

plt.hist(xs,bins=30)
print(xs.shape)
# Out:
# (200,)

# %%
# Caminho absoluto até a pasta "src"
from Distribuitions.distribuitions import *

metodo = 'mvs'

distr = LogPearsonIII()

distr.fit(xs, method=metodo)   # ajusta os dados pelo método dos momentos
print(distr.scipy_params)     # mostra os parâmetros ajustados
# distr.fitTest()
distr.describe_plot()
# Out:
# (-0.28210874214761983, 4.993532144690109, 0.5072855981593674)
